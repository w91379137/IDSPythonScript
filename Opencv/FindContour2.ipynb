# %% [markdown]
# ndarray 取值方法
# https://docs.scipy.org/doc/numpy-dev/user/quickstart.html
#
# matplotlib 繪圖方法
#
# http://www.cnblogs.com/wei-li/archive/2012/05/23/2506940.html
# https://stackoverflow.com/questions/34931864/matplotlib-use-fill-between-to-make-coloured-triangles
# http://matplotlib.org/api/pyplot_api.html

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
import cv2
  
im = cv2.imread('test1.png')
imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(imgray,127,255,0)
image, contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
print "there are " + str(len(contours)) + " contours"
# Out:
# there are 2 contours

# %%
cnt = contours[0]
print "there are " + str(len(cnt)) + " points in contours[0]"
approx = cv2.approxPolyDP(cnt,30,True)
print "after approx, there are " + str(len(approx)) + " points"
#print approx
plt.fill(approx[:,0][:,0], approx[:,0][:,1])
# Out:
# there are 351 points in contours[0]
# after approx, there are 10 points

# %%
cnt = contours[1]
print "there are " + str(len(cnt)) + " points in contours[1]"
approx = cv2.approxPolyDP(cnt,30,True)
print "after approx, there are " + str(len(approx)) + " points"
#print approx
#cv2.drawContours(im,[approx],0,(0,255,0),-1)
plt.fill(approx[:,0][:,0], approx[:,0][:,1])
# Out:
# there are 8 points in contours[1]
# after approx, there are 4 points

# %%
hull = cv2.convexHull(contours[0])
plt.fill(hull[:,0][:,0], hull[:,0][:,1])
