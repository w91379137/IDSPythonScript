# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
image = cv2.imread('/Users/w91379137/Downloads/IMG_2281.JPG')
plt.imshow(image)

# %%
r = image[:, :, 0]
maskx = cv2.inRange(r, 0, 100)
r_save = cv2.bitwise_and(r, r , mask = maskx)
plt.imshow(r_save, cmap='gray')

# %%
import numpy as np

# %%
r = image[:, :, 0]

#maskr1 = np.where( r > 0 )
maskr2 = np.where( r < 100 , r ,0)
#r[maskr1] = 0
#r[maskr2] = 0
plt.imshow(maskr2, cmap='gray')

# %%
test = np.linspace(1, 10 , 10)
k = np.where( test > 5 , test ,0)
print(k)
# Out:
# [  0.   0.   0.   0.   0.   6.   7.   8.   9.  10.]
